# %% [markdown]
# ## DATA VIZ PROJECT DRAFT

# %%
import pandas as pd
from matplotlib import pyplot as plt

#EURO - USD PAST 5 YEARS Trend
x = [2015, 2016, 2017, 2018, 2019, 2020]
y = [1.09, 1.05, 1.20, 1.15, 1.12, 1.20]
plt.plot(x,y)
plt.title("Euro to USD past 5 years trend") 
plt.xlabel("Years")
plt.ylabel("Rate ")
plt.show()

# %%
#EURO - USD 2021 FORECAST
x = ["Jan", "Feb", "Mar", "Apr", "May", "June", "July", "Aug", "Sep", "Oct", "Nov", "Dec"]
y = [1.247, 1.278, 1.269, 1.245, 1.261, 1.299, 1.314, 1.333, 1.323, 1.324, 1.316, 1.302]
plt.plot(x,y)
plt.title("Euro to USD 2021 forecast") 
plt.xlabel("Years")
plt.ylabel("Rate ")
plt.show()

# %%
#USD - CNY PAST 5 YEARS TREND
x = [2015, 2016, 2017, 2018, 2019, 2020]
y = [6.48, 6.95, 6.51, 6.88, 6.96, 6.57]
plt.plot(x,y)
plt.title("USD TO CNY past 5 years trend") 
plt.xlabel("Years")
plt.ylabel("Rate ")
plt.show()

# %%
#USD TO CNY 2021 FORECAST
x = ["Jan", "Feb", "Mar", "Apr", "May", "June", "July", "Aug", "Sep", "Oct", "Nov", "Dec"]
y = [6.58, 6.59, 6.60, 6.61, 6.65, 6.66, 6.68, 6.71, 6.71, 6.71, 6.74, 6.77]
plt.plot(x,y)
plt.title("USD TO CNY 2021 forecast") 
plt.xlabel("Years")
plt.ylabel("Rate ")
plt.show()

# %%
#USD TO JPY PAST 5 YEARS TREND
x = [2015, 2016, 2017, 2018, 2019, 2020]
y = [120.27, 116.96, 112.69, 109.66, 108.68, 104.06]
plt.plot(x,y)
plt.title("USD TO JPY past 5 years trend") 
plt.xlabel("Years")
plt.ylabel("Rate ")
plt.show()

# %%
#USD TO JPY 2021 FORECAST
x = ["Jan", "Feb", "Mar", "Apr", "May", "June", "July", "Aug", "Sep", "Oct", "Nov", "Dec"]
y = [103.84, 103.55, 102.66, 102.39, 102.38, 100.38, 100.56, 101.18, 100.79, 100.27, 99.99, 99.69]
plt.plot(x,y)
plt.title("USD TO JPY 2021 forecast") 
plt.xlabel("Years")
plt.ylabel("Rate ")
plt.show()

# %%
#USD TO INR PAST 5 YEARS TREND
x = [2015, 2016, 2017, 2018, 2019, 2020]
y = [66.26, 68.21, 64.08, 69.93, 71.41, 73.76]
plt.plot(x,y)
plt.title("USD TO INR past 5 years trend") 
plt.xlabel("Years")
plt.ylabel("Rate ")
plt.show()

# %%
#USD TO INR 2021 FORECAST
x = ["Jan", "Feb", "Mar", "Apr", "May", "June", "July", "Aug", "Sep", "Oct", "Nov", "Dec"]
y = [71.99, 71.46, 72.43, 72.71, 71.11, 70.51, 70.44, 70.64, 70.72, 72.84, 73.50, 73.68]
plt.plot(x,y)
plt.title("USD TO INR 2021 forecast") 
plt.xlabel("Years")
plt.ylabel("Rate ")
plt.show()
