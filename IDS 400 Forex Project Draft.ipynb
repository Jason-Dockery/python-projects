# %%
import pandas as pd
#insert other imports here

# %%
# Currency Converter function
# I used the currencies of the top 5 international economies.
# Basically type-in the abbrevations of 2 currencies and enter the amount of money you would like to convert. 

def converter():
    currencyPre = input (" Which currency would you like to convert from? \n\n >USD, EUR, CNY, JPY, INR< \n\n Your choice: ")
    
    print("- " * 40)
    
    currencyPos = input (" Which currency would you like to convert to? \n\n >USD, EUR, CNY, JPY, INR< \n\n Your choice: ")
    
    print("- " * 40)
    
    if currencyPre == "USD":
        
        if currencyPos == "EUR":
            USD = float(input ("\nEnter your amount of USD that would like to convert: ")) 
            print("- " * 40)
            EUR = USD * 0.8537
            print("\n", "$ %0.2f" %USD, "Dollars", "= ~ € %0.2f" %EUR, "Euros")
            # insert currency csv plots here
        
        elif currencyPos == "CNY":
            USD = float(input ("\nEnter your amount of USD that would like to convert: ")) 
            print("- " * 40)
            CNY = USD * 6.576
            print("\n", "$ %0.2f" %USD, "Dollars", "= ~ ¥ %0.2f" %CNY, "Yuans")
            # insert currency csv plots here
        
        elif currencyPos == "JPY":
            USD = float(input ("\nEnter your amount of USD that would like to convert: ")) 
            print("- " * 40)
            JPY = USD * 104.06
            print("\n", "$ %0.2f" %USD, "Dollars", "= ~ ¥ %0.2f" %JPY, "Yens")
            # insert currency csv plots here
            
        elif currencyPos == "INR":
            USD = float(input ("\nEnter your amount of USD that would like to convert: ")) 
            print("- " * 40)
            INR = USD * 73.764
            print("\n", "$ %0.2f" %USD, "Dollars", "= ~ ₹ %0.2f" %INR, "Rupees")
            # insert currency csv plots here
            
        else: 
            print("Error: Incorrect secondary currency entered.")
            
    
    elif currencyPre == "EUR":
        
        if currencyPos == "USD":
            EUR = float(input ("\nEnter your amount of EUR that would like to convert: "))
            print("- " * 40)
            USD = EUR * 1.1962
            print("\n", "€ %0.2f" %EUR, "Euros", "= ~ $ %0.2f" %USD, "Dollars")
            # insert currency csv plots here
        
        elif currencyPos == "CNY":
            EUR = float(input ("\nEnter your amount of EUR that would like to convert: "))
            print("- " * 40)
            CNY = EUR * 7.8662
            print("\n", "€ %0.2f" %EUR, "Euros", "= ~ ¥ %0.2f" %CNY, "Yuans")   
            # insert currency csv plots here
        
        elif currencyPos == "JPY":
            EUR = float(input ("\nEnter your amount of EUR that would like to convert: "))
            print("- " * 40)
            JPY = EUR * 124.43
            print("\n", "€ %0.2f" %EUR, "Euros", "= ~ ¥ %0.2f" %JPY, "Yens")
            # insert currency csv plots here
            
        elif currencyPos == "INR":
            EUR = float(input ("\nEnter your amount of EUR that would like to convert: "))
            print("- " * 40)
            INR = EUR * 88.2358
            print("\n", "€ %0.2f" %EUR, "Euros", "= ~ ₹ %0.2f" %INR, "Rupees")
            # insert currency csv plots here
        
        else: 
            print("Error: Incorrect secondary currency entered.")

                
    elif currencyPre == "CNY":
        
        if currencyPos == "USD":
            CNY = float(input ("\nEnter your amount of CNY that would like to convert: "))
            print("- " * 40)
            USD = CNY *.1520
            print("\n", "¥ %0.2f" %CNY, "Yuans", "= ~ $ %0.2f" %USD, "Dollars")
            # insert currency csv plots here
        
        elif currencyPos == "EUR":
            CNY = float(input ("\nEnter your amount of CNY that would like to convert: "))
            print("- " * 40)
            EUR = CNY * .1271
            print("\n", "¥ %0.2f" %CNY, "Yuans", "= ~ € %0.2f" %CNY, "Euros")   
            # insert currency csv plots here
        
        elif currencyPos == "JPY":
            CNY = float(input ("\nEnter your amount of CNY that would like to convert: "))
            print("- " * 40)
            JPY = CNY * 15.82
            print("\n", "¥ %0.2f" %CNY, "Yuans", "= ~ ¥ %0.2f" %JPY, "Yens")
            # insert currency csv plots here
            
        elif currencyPos == "INR":
            CNY = float(input ("\nEnter your amount of CNY that would like to convert: "))
            print("- " * 40)
            INR = CNY * 11.2137
            print("\n", "¥ %0.2f" %CNY, "Yuans", "= ~ ₹ %0.2f" %INR, "Rupees")
            # insert currency csv plots here
        
        else: 
            print("Error: Incorrect secondary currency entered.")
            
                
    elif currencyPre == "JPY":
        
        if currencyPos == "USD":
            JPY = float(input ("\nEnter your amount of JPY that would like to convert: "))
            print("- " * 40)
            USD = JPY * 0.0096
            print("\n", "¥ %0.2f" %JPY, "Yens", "= ~ $ %0.2f" %USD, "Dollars")
            # insert currency csv plots here
        
        elif currencyPos == "CNY":
            JPY = float(input ("\nEnter your amount of JPY that would like to convert: "))
            print("- " * 40)
            CNY = JPY * 0.0631
            print("\n", "¥ %0.2f" %JPY, "Yens", "= ~ ¥ %0.2f" %CNY, "Yuans")   
            # insert currency csv plots here
        
        elif currencyPos == "EUR":
            JPY = float(input ("\nEnter your amount of JPY that would like to convert: "))
            print("- " * 40)
            EUR = JPY * 0.0080
            print("\n", "¥ %0.2f" %JPY, "Yens", "= ~ € %0.2f" %EUR, "Euros")
            # insert currency csv plots here
            
        elif currencyPos == "INR":
            JPY = float(input ("\nEnter your amount of JPY that would like to convert: "))
            print("- " * 40)
            INR = JPY * 0.7082
            print("\n", "¥ %0.2f" %JPY, "Yens", "= ~ ₹ %0.2f" %INR, "Rupees")
            # insert currency csv plots here
        
        else: 
            print("Error: Incorrect secondary currency entered.")

                
    elif currencyPre == "INR":
        
        if currencyPos == "USD":
            INR = float(input ("\nEnter your amount of INR that would like to convert: "))
            print("- " * 40)
            USD = INR * 0.0135
            print("\n", "₹ %0.2f" %INR, "Rupees", "= ~ $ %0.2f" %USD, "Dollars")
            # insert currency csv plots here
        
        elif currencyPos == "CNY":
            INR = float(input ("\nEnter your amount of INR that would like to convert: "))
            print("- " * 40)
            CNY = INR * 0.0889
            print("\n", "₹ %0.2f" %INR, "Rupees", "= ~ ¥ %0.2f" %CNY, "Yuans")   
            # insert currency csv plots here
        
        elif currencyPos == "JPY":
            INR = float(input ("\nEnter your amount of INR that would like to convert: "))
            print("- " * 40)
            JPY = INR *1.41
            print("\n", "₹ %0.2f" %INR, "Rupees", "= ~ ¥ %0.2f" %JPY, "Yens")
            # insert currency csv plots here
            
        elif currencyPos == "EUR":
            INR = float(input ("\nEnter your amount of INR that would like to convert: "))
            print("- " * 40)
            EUR = INR * 0.0113
            print("\n", "₹ %0.2f" %INR, "Rupees", "= ~ € %0.2f" %EUR, "Euros")
            # insert currency csv plots here
            
        else: 
            print("Error: Incorrect secondary currency entered.")
        
def repeat(): 
    print("- " * 40)
    opt = input("Would you like to convert again? \n\n\t Yes or No? : ")
    if opt == "Yes":
        converter()
    elif opt == "No":
        print("\nConversion complete. \t Program is now closing. \t Thank you.")
    else: 
        print("Error: Incorrect response entered. \n Program is closing.")

# %%
converter()
repeat()
# Out:
#  Which currency would you like to convert from?
#
#  >USD, EUR, CNY, JPY, INR<
#
#  Your choice: CNY
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#  Which currency would you like to convert to?
#
#  >USD, EUR, CNY, JPY, INR<
#
#  Your choice: JPY
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# Enter your amount of CNY that would like to convert: 2536
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
#  ¥ 2536.00 Yuans = ~ ¥ 40119.52 Yens
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Would you like to convert again?
#
# 	 Yes or No? : No
#
# Conversion complete. 	 Program is now closing. 	 Thank you.
